# %%
import geopandas as gpd

# Load the zip code geography data
gdf = gpd.read_file('../api/src/migrations/data/secret/20260227-zip-code-data.csv')
gdf_sample = gpd.read_file("/Users/jared/Downloads/ZIP_Boundaries_LA_Metro_May2024 2/ZIP_Boundaries_LA_Metro_May2024_csv.csv")

# %%
# gdf.head()
gdf['COLOR'].unique()
gdf_filtered = gdf[gdf['ZIP'].isin(gdf_sample['ZIP'])]
print(len(gdf_filtered))
print(len(gdf_sample))
# gdf_filtered.to_csv('output.csv', index=False)


gdf_filtered_2 = gdf_sample[gdf_sample['ZIP'].isin(gdf['ZIP'])]
print(len(gdf_filtered_2))
print(len(gdf_sample))
gdf_filtered.head()
